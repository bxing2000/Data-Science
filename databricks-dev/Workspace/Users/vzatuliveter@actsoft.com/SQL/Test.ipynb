# %%
Class.forName("com.microsoft.sqlserver.jdbc.SQLServerDriver")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1041052864342356&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>Class<span class="ansiyellow">.</span>forName<span class="ansiyellow">(</span><span class="ansiblue">&quot;com.microsoft.sqlserver.jdbc.SQLServerDriver&quot;</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;Class&apos; is not defined</div>

# %%
host = "qadev1.database.windows.net"
database = "CabClient1"

# Create the JDBC URL without passing in the user and password parameters.
#jdbcUrl = f"jdbc:sqlserver://{jdbcHostname}:{jdbcPort};database={jdbcDatabase}"
cnnStr = "jdbc:sqlserver://" + host + ";database=" + database

# Create a Properties() object to hold the parameters.
import java.util.Properties

cnn = Properties()
cnn.put("user", "AnalyticsTest")
cnn.put("password", "br8jDq8YAhS30VGc2ioD2e62yOdPpa")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ImportError</span>                               Traceback (most recent call last)
# <span class="ansigreen">&lt;command-3913306750768351&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      8</span> <span class="ansiyellow"></span>
# <span class="ansigreen">      9</span> <span class="ansired"># Create a Properties() object to hold the parameters.</span><span class="ansiyellow"></span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 10</span><span class="ansiyellow"> </span><span class="ansigreen">import</span> java<span class="ansiyellow">.</span>util<span class="ansiyellow">.</span>Properties<span class="ansiyellow"></span>
# <span class="ansigreen">     11</span> <span class="ansiyellow"></span>
# <span class="ansigreen">     12</span> cnn <span class="ansiyellow">=</span> Properties<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansired">ImportError</span>: No module named &apos;java&apos;</div>

# %%
// Note: The parentheses are required.
val pushdown_query = "(select * from employees where emp_no < 10008) emp_alias"
val df = spark.read.jdbc(url=jdbcUrl, table=pushdown_query, properties=connectionProperties)
display(df)

# %%
--version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-3913306750768353&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span><span class="ansiyellow">-</span><span class="ansiyellow">-</span>version<span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;version&apos; is not defined</div>
