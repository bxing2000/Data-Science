# %%
# %run "../Common/Common"

# %%
dbutils.widgets.combobox(TextConstant.environment, Environment.qa.name, [l.name for l in Environment])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
environment = Environment[dbutils.widgets.get(TextConstant.environment)]

lakeName = environment.value['dataLakeName']

spark.conf.set(
  "fs.azure.account.key."+lakeName+".blob.core.windows.net",
  dbutils.secrets.get(scope='default',key="data-lake-storage-key")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run "./CreateTable"

# %%
# %run "./CopyClient"

# %%
for instance in environment.value['instances']:
  CopyClientData(lakeName, instance)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">LakeName: qaanalytics
# Instance: att
# InstanceId: 17
# Reading data since 2000-01-01 00:00:00
# Load Geofences data
# Load GeofenceTypes data
# Writing data...
# ...
# Writing data completed.
# 2020-07-27 09:19:11.030000
# Save {&#34;LastSyncDate&#34;:&#34;2020-07-27T09:19:11.030000&#34;}
# Wrote 45 bytes.
# LakeName: qaanalytics
# Instance: encore
# InstanceId: 23
# Reading data since 2000-01-01 00:00:00
# Load Geofences data
# Load GeofenceTypes data
# Writing data...
# ...
# Writing data completed.
# 2019-12-12 19:15:13.750000
# Save {&#34;LastSyncDate&#34;:&#34;2019-12-12T19:15:13.750000&#34;}
# Wrote 45 bytes.
# </div>
