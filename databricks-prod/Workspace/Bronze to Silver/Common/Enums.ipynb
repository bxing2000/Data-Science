# %%
from enum import Enum
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# class Instance(Enum):
#   att = 17
#   encore = 23

#   vfindia = 22
#   vfuk = 19
#   maxis = 24
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
class TextConstant:
  environment = 'Environment'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
class QaInstance(Enum):
  att = 17
  encore = 23
#   vfindia = 22
#   vfuk = 19
#   maxis = 24
#   attshield = 27
#   fedramp = 28
#   encorevault = 29

class ProdInstance(Enum):
  att = 50
  encore = 53
  vfindia = 52
  #vfuk = 54
  maxis = 56

class ProdSecureInstance(Enum):
  attshield = 57
  fedramp= 58
  encorevault = 59

class Environment(Enum):
  qa = { 
    'dataLakeName': "qaanalytics", 
    'instances': [e for e in QaInstance]
  }
  prod = { 
    'dataLakeName': "prodanalytics1", 
    'instances': [e for e in ProdInstance]
  }
  prodsecure = {    
    'dataLakeName': "analyticssecurityprod", 
    'instances': [e for e in ProdSecureInstance]
  }
  
#print(Environment.qa.value['instances'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# from enum import Enum

class TableParams(Enum):
  DataSource = 1
  TableName = 2
  PkColumns = 3
  ModificationTimeColumn = 4
  
class BronzeTable(Enum):
  Accounts_Dynamics = { TableParams.DataSource: 'dynamics', 
            TableParams.TableName: 'account', 
            TableParams.PkColumns: 'accountid', 
            TableParams.ModificationTimeColumn: 'ModifiedOn', 
          }
  Accounts_Billing = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'accounts', 
            TableParams.PkColumns: 'AccountId', 
            TableParams.ModificationTimeColumn: 'ModificationDate', 
          }
  Audits = { TableParams.DataSource: 'dynamics', 
            TableParams.TableName: 'audit', 
            TableParams.PkColumns: 'AuditId', 
            TableParams.ModificationTimeColumn: 'CreatedOn', 
          }
  Carriers = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'carriers'
          }
  Clients = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'clients_client', 
            TableParams.PkColumns: 'CompanyId, ClientId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Companies_Billing = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'companies', 
            TableParams.PkColumns: 'CompanyId', 
            TableParams.ModificationTimeColumn: 'ModificationDate'
          }
  Companies_Central = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'companies_central', 
            TableParams.PkColumns: 'CompanyId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Companies_Client = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'companies_client', 
            TableParams.PkColumns: 'CompanyId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }   
  CompanyFeatures = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'company_features_client', 
            TableParams.PkColumns: 'CompanyId, CompanyFeatureId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          } 
  CompanyModules = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'company_modules_client', 
            TableParams.PkColumns: 'CompanyId, CompanyModuleId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          } 
  Devices_CabManager = { TableParams.DataSource: 'cab/cabmanager', 
            TableParams.TableName: 'devices', 
            TableParams.PkColumns: 'DeviceId', 
            TableParams.ModificationTimeColumn: 'UpdatedOn'
          } 
  Devices_Central = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'devices_central', 
            TableParams.PkColumns: 'CompanyId, DeviceId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          } 
  Devices_Client = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'devices_client', 
            TableParams.PkColumns: 'CompanyId, DeviceId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          } 
  FormHeaders = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'form_headers_client', 
            TableParams.PkColumns: 'CompanyId, FormHeaderId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Geofences = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'geofences_client', 
            TableParams.PkColumns: 'CompanyId, GeofenceId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Groups = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'groups_client'
          }
  GeofenceTypes = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'geofence_types_client', 
            TableParams.PkColumns: 'CompanyId, GeofenceTypeId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Incidents = { TableParams.DataSource: 'dynamics', 
            TableParams.TableName: 'incident', 
            TableParams.PkColumns: 'IncidentId', 
            TableParams.ModificationTimeColumn: 'ModifiedOn'
          }
  Instances = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'cab_instance_configs'
          }
  InstanceTiers = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'instance_tiers'
          }
  Licenses = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'licenses', 
            TableParams.PkColumns: 'LicenseId', 
            TableParams.ModificationTimeColumn: 'ModificationDate'
          }
  Modules = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'modules_central'
          }
  Opportunities = { TableParams.DataSource: 'dynamics', 
            TableParams.TableName: 'opportunity', 
            TableParams.PkColumns: 'opportunityid', 
            TableParams.ModificationTimeColumn: 'ModifiedOn'
          }
  OrderHeaders = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'order_headers_client', 
            TableParams.PkColumns: 'CompanyId, OrderId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  OrderStatusesNames = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'order_statuses_names_client', 
            TableParams.PkColumns: 'CompanyId, CompanyModuleId, CompanyModuleVersion, OrderStatusIndex', 
            TableParams.ModificationTimeColumn: 'CreatedUtc'
          }
  PaymentMethods = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'payment_methods', 
            TableParams.PkColumns: 'PaymentMethodId', 
            TableParams.ModificationTimeColumn: 'ModificationDate'
          }
  PaymentSchedules = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'payment_schedules', 
            TableParams.PkColumns: 'PaymentScheduleId', 
            TableParams.ModificationTimeColumn: 'ModificationDate'
          }
  ProductPriceLevels = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'product_price_levels'
          }
  Products = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'products'
          }
  SentMessages = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'sent_messages_client', 
            TableParams.PkColumns: 'CompanyId, MessageId', 
            TableParams.ModificationTimeColumn: 'ModifiedDateUtc'
          }
  SOCs = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'socs'
          }
  StringMap = { TableParams.DataSource: 'dynamics', 
            TableParams.TableName: 'string_map'
          }
  TimekeepingStatuses = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'timekeeping_statuses_client', 
            TableParams.PkColumns: 'CompanyId, TimekeepingStatusId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Tiers = { TableParams.DataSource: 'cab/billing', 
            TableParams.TableName: 'instance_tiers'
          }
  Trips = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'trips_client', 
            TableParams.PkColumns: 'CompanyId, DeviceId, StartUtcTime', 
            TableParams.ModificationTimeColumn: 'StartUtcTime'
          }
  Users = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'users_client', 
            TableParams.PkColumns: 'CompanyId, UserId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Vehicles = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'vehicles_client', 
            TableParams.PkColumns: 'CompanyId, VehicleId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }
  Verticals = { TableParams.DataSource: 'cab/operational', 
            TableParams.TableName: 'verticals_central', 
            TableParams.PkColumns: 'VerticalId', 
            TableParams.ModificationTimeColumn: 'ModifiedUtc'
          }

# print(BronzeTables.Trips.value[TableParams.DataSource])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
