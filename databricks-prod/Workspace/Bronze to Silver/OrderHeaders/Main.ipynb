# %%
# %run "../Common/Common"

# %%
dbutils.widgets.combobox(TextConstant.environment, Environment.qa.name, [l.name for l in Environment])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
environment = Environment[dbutils.widgets.get(TextConstant.environment)]

lakeName = environment.value['dataLakeName']

spark.conf.set(
  "fs.azure.account.key."+lakeName+".blob.core.windows.net",
  dbutils.secrets.get(scope='default',key="data-lake-storage-key")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run "./CreateTable"

# %%
# %run "./CopyClient"

# %%
print('=== OrderHeaders ===') 

for e in environment.value['instances']:
  CopyClientData(lakeName, e)
  print()
  
print('=== end OrderHeaders ===', end='\n\n')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">=== OrderHeaders ===
# LakeName: qaanalytics
# Instance: att
# InstanceId: 17
# Reading data since 2000-01-01 00:00:00
# Load OrderHeaders data
# Load CompanyModules data
# Load Users data
# Load Clients data
# Load OrderStatusesNames data
# Preparing data to write...
# Writing data...
# MinYear 2015
# MaxYear 2020
# LastSyncDate 2020-07-29 12:58:16
# Writing data completed.
# 2020-07-30 22:40:40.830000
# Save {&#34;LastSyncDate&#34;:&#34;2020-07-30T22:40:40.830000&#34;}
# Wrote 45 bytes.
#
# LakeName: qaanalytics
# Instance: encore
# InstanceId: 23
# Reading data since 2000-01-01 00:00:00
# Load OrderHeaders data
# Load CompanyModules data
# Load Users data
# Load Clients data
# Load OrderStatusesNames data
# Preparing data to write...
# Writing data...
# MinYear 2015
# MaxYear 2020
# LastSyncDate 2020-02-27 13:23:06
# Writing data completed.
# 2020-02-27 13:23:23.710000
# Save {&#34;LastSyncDate&#34;:&#34;2020-02-27T13:23:23.710000&#34;}
# Wrote 45 bytes.
#
# === end OrderHeaders ===
#
# </div>
