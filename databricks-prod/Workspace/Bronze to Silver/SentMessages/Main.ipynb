# %%
# %run "../Common/Common"

# %%
dbutils.widgets.combobox(TextConstant.environment, Environment.qa.name, [l.name for l in Environment])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
environment = Environment[dbutils.widgets.get(TextConstant.environment)]

lakeName = environment.value['dataLakeName']

spark.conf.set(
  "fs.azure.account.key."+lakeName+".blob.core.windows.net",
  dbutils.secrets.get(scope='default',key="data-lake-storage-key")
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run "./CreateTable"

# %%
# %run "./CopyClient"

# %%
for ins in environment.value['instances']:
  CopyClientData(lakeName, ins)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">LakeName: qaanalytics
# Instance: att
# InstanceId: 17
# Reading data since 2000-01-01 00:00:00
# Load SentMessages data
# Load Users data
# Preparing data to write...
# Writing data...
# MinYear 2014
# MaxYear 2020
# LastSyncDate 2020-07-23 05:58:54
# Write completed.
# Updating last sync date.
# Save {&#34;LastSyncDate&#34;:&#34;2020-07-23T05:58:54.0&#34;}
# Wrote 40 bytes.
# Done.
#
# LakeName: qaanalytics
# Instance: encore
# InstanceId: 23
# Reading data since 2000-01-01 00:00:00
# Load SentMessages data
# Load Users data
# Preparing data to write...
# Writing data...
# MinYear 2014
# MaxYear 2019
# LastSyncDate 2019-11-05 18:05:30
# Write completed.
# Updating last sync date.
# Save {&#34;LastSyncDate&#34;:&#34;2019-11-05T18:05:30.0&#34;}
# Wrote 40 bytes.
# Done.
#
# </div>
