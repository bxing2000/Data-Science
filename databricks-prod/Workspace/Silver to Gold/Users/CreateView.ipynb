# %%
# %sql
drop view if exists gold.Users
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
create view gold.Users
as
  select 
        u.InstanceId
      , u.CompanyId 
      , u.UserId 
      , u.CreatedUtc 
      , u.FirstName 
      , u.LastName 
      , u.RoleName 
      , u.Deleted 
      , u.IsActive 
      , u.ActivationDate 
      , u.DeactivationDate 
      , u.EPTTNumber 
      , u.EPTTWebMDN 
      , u.Phone 
      , u.Email 
      , u.GroupName
      , u.EPTTEnabled 
      , u.EmailVerifiedUtc 
      , u.IsEmailVerified 
      , u.EmailVerificationSentUtc 
      , u.EmployeeNumber 
      , u.HasImage 
      , u.PasswordChangedUtc 
      , u.PasswordChangeReminderSentUtc 
      , u.LicenseType 
      , u.LicenseTypeName 
      , u.MobileOnly 
      , u.IsAccountOwner
  from delta.`/mnt/silver/cab/users` u
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.AnalysisException: View `gold`.`Users` already exists. If you want to update the view definition, please use ALTER VIEW AS or CREATE OR REPLACE VIEW AS;
# 	at org.apache.spark.sql.execution.command.CreateViewCommand.run(views.scala:151)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:70)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:68)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.executeCollect(commands.scala:79)
# ...
