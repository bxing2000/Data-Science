# %%
# %sql
drop view if exists gold.Timekeeping

# %%
# %sql
create view gold.Timekeeping
as
  select 
        InstanceId
      , CompanyId
      , TimekeepingStatusId
      , ModuleName
      , CompanyModuleVersion
      , UserName
      , StatusName
      , StartUtcTime
      , StartLocalTime
      , EndUtcTime
      , EndLocalTime
      , TotalBreaksMinutes
      , PaidDurationMinutes
      , RootTimekeepingStatusId
      , RootStartUtcTime
      , IsRoot
      , StartDeviceName
      , StartSubRegionName
      , EndSubRegionName
      , EndGPSProcessed
      , StartLat
      , StartLon
      , StartGeofenceName
      , StartGPSProcessed
      , EndLat
      , EndLon
      , EndGeofenceName
      , StartAddressLine1
      , StartAddressLine2
      , StartCity
      , StartRegionName
      , StartPostalCode
      , StartCountryCode
      , EndAddressLine1
      , EndAddressLine2
      , EndCity
      , EndRegionName
      , EndPostalCode
      , EndCountryCode
      , EndDeviceName
      , StartRegionCode
      , StartSubRegionCode
      , EndRegionCode
      , EndSubRegionCode
      , CreatedUtc
      , ModifiedUtc
      , Version
      , Approved
  from delta.`/mnt/silver/cab/timekeeping_statuses`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
