# %%
# %sql
drop view if exists gold.Trips

# %%
# %sql
create view gold.Trips
as
  select 
        InstanceId
      , CompanyId
      , DeviceName
      , StartUtcTime
      , StartLocalTime
      , StartLat
      , StartLon
      , EndUtcTime
      , EndLocalTime
      , EndLat
      , EndLon
      , DistanceMiles
      , OdometerMiles
      , IdleTimeSeconds
      , StopTimeSeconds
      , TimeSinceLastTripSeconds
      , ModifiedUtc
      , Deleted
      , StartCity
      , StartRegionName
      , StartPostalCode
      , StartAddressLine1
      , StartAddressLine2
      , StartCountryCode
      , EndCity
      , EndRegionName
      , EndPostalCode
      , EndAddressLine1
      , EndAddressLine2
      , EndCountryCode
      , StartGeofenceName
      , EndGeofenceName
      , StartSubRegionName
      , EndSubRegionName
      , StartRegionCode
      , StartSubRegionCode
      , EndRegionCode
      , EndSubRegionCode
      , CreatedUtc
      , UserName
      , UserLinkedToVehicle
      , VehicleName
      , ModifiedDate
  from delta.`/mnt/silver/cab/trips`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
