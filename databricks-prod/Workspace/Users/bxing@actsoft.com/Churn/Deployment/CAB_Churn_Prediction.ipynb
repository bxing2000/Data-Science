# %% [markdown]
# **This notebook predicts Churn for CAB **
#
# **Note:**
# - For registered users only
# - Prediction outputs spark dataframe with churn probability for each currently active company

# %% [markdown]
# Select companies for prediction

# %%
from datetime import datetime

# end date for the prediction, typically in sync with the latest data.
pred_datetime = datetime.today()

# start date for license activation
start_dateime = datetime(2000, 1, 1)

# DON'T CHANGE!!! registered users only. 
registered_only = True
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Creates input dataframe in Pandas using above criteria

# %%
# %run ./CAB_Churn_Input
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">billable companies join with licenses:  1616
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# only pick still active ones to predict
# active_account = billable_account_churn_cache.filter(col('Deactivation').isNull())

active_account = billable_account_churn_cache
active_account = active_account.drop(active_account.CompanyName).drop(active_account.City).drop(active_account.RegionName) \
                               .drop(active_account.PostalCode).drop(active_account.CountryCode).drop(active_account.Culture)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(active_account)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CompanyId</th><th>InstanceId</th><th>Tier</th><th>IsSetupComplete</th><th>UserIntegrationType</th><th>AccountId</th><th>AccountName</th><th>Activation</th><th>Expiration</th><th>Deactivation</th><th>Duration</th><th>StandaloneLicenses</th><th>AddonLicenses</th><th>Churn</th><th>Incidents</th><th>Trips</th><th>Forms</th><th>Timekeeping</th><th>Orders</th></tr></thead><tbody><tr><td>872</td><td>50</td><td>30</td><td>true</td><td>0</td><td>744</td><td>TECS ELECTRIC LTD</td><td>2016-01-27T00:00:00.000+0000</td><td>null</td><td>null</td><td>1813</td><td>28</td><td>15</td><td>0</td><td>0</td><td>0</td><td>5</td><td>4</td><td>690</td></tr><tr><td>965</td><td>53</td><td>10</td><td>true</td><td>0</td><td>21488</td><td>Southwest Center</td><td>2018-02-26T00:00:00.000+0000</td><td>null</td><td>null</td><td>1052</td><td>17</td><td>0</td><td>0</td><td>10</td><td>19994</td><td>1</td><td>0</td><td>0</td></tr><tr><td>2917</td><td>50</td><td>10</td><td>true</td><td>0</td><td>2778</td><td>LADC COMPANIES, INC.</td><td>2016-03-10T00:00:00.000+0000</td><td>null</td><td>null</td><td>1770</td><td>10</td><td>9</td><td>0</td><td>0</td><td>1709</td><td>0</td><td>69</td><td>2</td></tr><tr><td>3354</td><td>53</td><td>10</td><td>true</td><td>0</td><td>23396</td><td>BAYFIELD ENTERPRISES INC</td><td>2019-10-02T00:00:00.000+0000</td><td>null</td><td>null</td><td>469</td><td>11</td><td>5</td><td>0</td><td>0</td><td>4116</td><td>0</td><td>0</td><td>0</td></tr><tr><td>3549</td><td>53</td><td>30</td><td>true</td><td>0</td><td>23575</td><td>Robi Security Service</td><td>2020-01-21T00:00:00.000+0000</td><td>null</td><td>null</td><td>358</td><td>5</td><td>2</td><td>0</td><td>0</td><td>0</td><td>5</td><td>11</td><td>1</td></tr><tr><td>8245</td><td>50</td><td>20</td><td>true</td><td>0</td><td>6598</td><td>Discount Fence USA</td><td>2017-06-27T00:00:00.000+0000</td><td>null</td><td>null</td><td>1296</td><td>21</td><td>11</td><td>0</td><td>5</td><td>15817</td><td>1261</td><td>428</td><td>40</td></tr><tr><td>9872</td><td>50</td><td>10</td><td>true</td><td>0</td><td>7910</td><td>Interstate PDX Shuttles</td><td>2017-09-28T00:00:00.000+0000</td><td>null</td><td>null</td><td>1203</td><td>25</td><td>0</td><td>0</td><td>0</td><td>36069</td><td>0</td><td>0</td><td>2825</td></tr><tr><td>11476</td><td>50</td><td>30</td><td>true</td><td>0</td><td>9228</td><td>Surfrider Foundation</td><td>2018-01-30T00:00:00.000+0000</td><td>null</td><td>null</td><td>1079</td><td>19</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td><td>0</td></tr><tr><td>12142</td><td>50</td><td>10</td><td>true</td><td>0</td><td>10773</td><td>Eldredge Tracking</td><td>2018-03-08T00:00:00.000+0000</td><td>null</td><td>null</td><td>1042</td><td>10</td><td>0</td><td>0</td><td>1</td><td>5138</td><td>0</td><td>0</td><td>0</td></tr><tr><td>36507</td><td>50</td><td>30</td><td>true</td><td>0</td><td>18826</td><td>ARMSTRONG MASONRY REPAIR INC</td><td>2020-01-31T00:00:00.000+0000</td><td>null</td><td>null</td><td>348</td><td>6</td><td>0</td><td>0</td><td>0</td><td>0</td><td>303</td><td>2</td><td>32</td></tr><tr><td>2337</td><td>53</td><td>20</td><td>true</td><td>0</td><td>22564</td><td>A-O Painting, Inc</td><td>2018-11-26T00:00:00.000+0000</td><td>null</td><td>null</td><td>779</td><td>5</td><td>0</td><td>0</td><td>1</td><td>0</td><td>1332</td><td>0</td><td>0</td></tr><tr><td>2352</td><td>50</td><td>20</td><td>true</td><td>0</td><td>2213</td><td>Innovative Integrated Health</td><td>2016-06-27T00:00:00.000+0000</td><td>null</td><td>null</td><td>1661</td><td>97</td><td>53</td><td>0</td><td>70</td><td>98746</td><td>47418</td><td>332</td><td>40</td></tr><tr><td>3418</td><td>53</td><td>20</td><td>true</td><td>0</td><td>23464</td><td>PENDLEY HEATING AND AIR</td><td>2019-11-02T00:00:00.000+0000</td><td>null</td><td>null</td><td>438</td><td>33</td><td>7</td><td>0</td><td>2</td><td>25381</td><td>0</td>< ...

# %% [markdown]
# Convert spark dataframe to pandas for prediction

# %%
df = active_account.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df['InstanceId'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 50    1205
# 53     411
# Name: InstanceId, dtype: int64</div>

# %% [markdown]
# Features to include in the final dataframe as input

# %%
categorical_features = ["Tier", "UserIntegrationType"]
numerical_features = ["StandaloneLicenses", "AddonLicenses", "Duration", "Incidents", "Trips", "Forms", "Timekeeping", "Orders"]

df_final = df[categorical_features + numerical_features]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# **Churn prediction**

# %%
import mlflow

# load from model registry
model_name = 'CAB-Churn-Prediction-RegisteredOnly'
model_version = 'Version 10'
# model_name = 'CAB-Churn-Prediction-RegisterOnly-RF'
# model_version = 'Version 2'
stage = 'Production'
loaded_model = mlflow.pyfunc.load_model(model_uri=f"models:/{model_name}/{stage}")

# Predict
pred = loaded_model.predict(df_final)
# with np.printoptions(precision=2, suppress=True):
#     print(pred)

condition = (pred < 0.5)
noChurn = np.extract(condition, pred) 
print('no churn count is ', len(noChurn))

condition = (pred >= 0.5)
churn = np.extract(condition, pred) 
print('churn count is ', len(churn))
print('proporation of churn data ', len(churn)/len(pred))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">no churn count is  1378
# churn count is  238
# proporation of churn data  0.14727722772277227
# </div>

# %% [markdown]
# **Display churning probability for each company**

# %%
from pyspark.sql.types import StructType, StructField, LongType
from pyspark.sql.functions import avg, round, lit

pred_pd = pd.DataFrame(pred, columns=['Churn'])
pred_saprk = spark.createDataFrame(pred_pd, ['Churn'])

def with_column_index(sdf): 
    new_schema = StructType(sdf.schema.fields + [StructField("ColumnIndex", LongType(), False),])
    return sdf.rdd.zipWithIndex().map(lambda row: row[0] + (row[1],)).toDF(schema=new_schema)


df1 = with_column_index(pred_saprk)
df2 = with_column_index(active_account)

df_spark = df1.join(df2, df1.ColumnIndex == df2.ColumnIndex, 'inner').drop(df2.ColumnIndex).drop(df1.ColumnIndex).drop(df2.Churn).drop(df2.IsSetupComplete)

# add model and versino info to output:
df_spark = df_spark.withColumn('ModelVersion', lit(model_name + ': ' + model_version))
# add churn proba column
df_spark = df_spark.withColumn('Churn', round(col('Churn'), 3))

display(df_spark)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>