# %%
# %run ./config_All_Zones_A

# %%
companies = spark.read.format('delta').load("/mnt/silver/cab/companies").selectExpr("CompanyId","AccountId","TierId","InstanceId","IsActive","SetupCompletionTime")
accounts = spark.read.format('delta').load("/mnt/silver/cab/accounts").selectExpr("accountId AS AccountId","Status","IsTest","CreationDate","industrycode AS IndustryCode")
licenses = spark.read.format('delta').load("/mnt/silver/cab/licenses").selectExpr("LicenseId", "AccountId", "CompanyId", "InstanceId", "TierId", "Count AS LicenseCount","CreatedOn","OriginalActivationDate AS Activated","DeactDate AS Deactivated")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
merged_usage = spark.read.format('csv').load("/tmp/merged_usage.csv")
print(merged_usage)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1608854963186480&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# ...
