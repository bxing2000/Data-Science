# %%
#Another stat that may be interesting is average “life” expectancy(duration) of a customer based on some scenarios. These would just be pure stats not ML. Warren maybe you can pull these using Bills “Churn Dataframe” it #already as most(maybe all) of the data you will need?

#1.	Duration > 180 days – IE if we keep a customer longer than 180 days how does that change their avg duration
#2.	If they have completed setup
#3.	In license buckets
#a.	1-10, 11-50, 50-200, 200+
#4.	If they use forms
#5.	If they use orders
#6.	If they use timekeeping
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %run "../bxing@actsoft.com/Churn_Dataframe"

# %%
df.dtypes
